# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4604\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = "https://github.com/LiaMuliaa/datasetDS/raw/main/Laundry%20Places/laundryPlacesIndonesia.csv"
data = pd.read_csv(df)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   link                82 non-null     object
#  1   title               82 non-null     object
#  2   category            82 non-null     object
#  3   address             82 non-null     object
#  4   open_hours          82 non-null     object
#  5   popular_times       82 non-null     object
#  6   website             32 non-null     object
#  7   phone               78 non-null     object
#  8   plus_code           77 non-null     object
#  9   review_count        82 non-null     int64
#  10  review_rating       82 non-null     float64
#  11  reviews_per_rating  82 non-null     object
#  12  latitude            82 non-null     float64
#  13  longitude           82 non-null     float64
#  14  cid                 82 non-null     uint64
# ...

# %%
# Check for missing values
print("Missing values per column:")
print(data.isnull().sum())
# Out:
# Missing values per column:
# link                   0
# title                  0
# category               0
# address                0
# open_hours             0
# popular_times          0
# website               50
# phone                  4
# plus_code              5
# review_count           0
# review_rating          0
# reviews_per_rating     0
# latitude               0
# longitude              0
# cid                    0
# status                14
# descriptions          82
# reviews_link           1
# thumbnail              0
# timezone               0
# price_range           82
# data_id                0
# images                 0
# reservations          82
# order_online          71
# menu                   0
# owner                  0
# complete_address       0
# about                 53
# user_reviews           1
# dtype: int64

# %%
# Check data types
print("\nData types:")
print(data.dtypes)
# Out:
# Data types:
# link                   object
# title                  object
# category               object
# address                object
# open_hours             object
# popular_times          object
# website                object
# phone                  object
# plus_code              object
# review_count            int64
# review_rating         float64
# reviews_per_rating     object
# latitude              float64
# longitude             float64
# cid                    uint64
# status                 object
# descriptions          float64
# reviews_link           object
# thumbnail              object
# timezone               object
# price_range           float64
# data_id                object
# images                 object
# reservations          float64
# order_online           object
# menu                   object
# owner                  object
# complete_address       object
# about                  object
# user_reviews           object
# dtype: object

# %%
# Check for duplicate entries
print("\nNumber of duplicate entries:", data.duplicated().sum())
# Out:
# Number of duplicate entries: 2

# %%
data.head()
# Out:
#                                                 link  \
# 0  https://www.google.com/maps/place/Fresh+Clean+...
# 1  https://www.google.com/maps/place/Hade+Laundry...
# 2  https://www.google.com/maps/place/Laundry+Satu...
# 3  https://www.google.com/maps/place/Amala+Expres...
# 4  https://www.google.com/maps/place/Sorcha+Laund...
#
#                                                title         category  \
# 0                        Fresh Clean Laundry Bandung       Laundromat
# 1                          Hade Laundry Simpang Dago  Laundry service
# 2  Laundry Satuan-Laundry Kiloan-Laundry Express-...  Laundry service
# 3               Amala Express Laundry & Wet Cleaning       Laundromat
# 4  Sorcha Laundry Pajajaran (Laundry Antar Jemput...       Laundromat
#
#                                              address  \
# 0  Jl. Cijawura Hilir No.14, Cijaura, Kec. Buahba...
# 1  Jl. Ir. H. Juanda No.170, Lebak Siliwangi, Ban...
# 2  Jl. Pendawa No.25a, RW.68, Arjuna, Cicendo, Ba...
# ...

# %%
# Initialize a `MissingNo` object
mn = mn.MissingNo(df)

# Create a heatmap of missing values
mn.matrix(df, figsize=(10, 10), color_by='value')
plt.title('Missing Values Heatmap')
plt.show()

# Create a bar chart of missing values by column
mn.bar(df, figsize=(8, 6))
plt.title('Missing Values by Column')
plt.show()
